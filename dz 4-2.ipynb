# %% [markdown]
# ## Задача 4.2 (к лекции «Управляющие конструкции и коллекции» часть 2)

# %% [markdown]
# Дана переменная, в которой хранится список поисковых запросов пользователя (пример структуры данных приведен ниже). Вам необходимо написать программу, которая выведет на экран распределение количества слов в запросах в требуемом виде.
#
# Пример работы программы:
#
# queries = [
# ‘смотреть сериалы онлайн’,
# ‘новости спорта’,
# ‘афиша кино’,
# ‘курс доллара’,
# ‘сериалы этим летом’,
# ‘курс по питону’,
# ‘сериалы про спорт’,
# ]
#
# Результат:
#
# Поисковых запросов, содержащих 2 слов(а): 42.86%
#
# Поисковых запросов, содержащих 3 слов(а): 57.14%

# %% [markdown]
# ## Вопрос
# ##### мне не нравится как я вывел итоговый результат. Если я правильно понимаю, то при оформлении выводящей строки проценты нужно(можно) как то так оформлять {:.2%}. Но, если я так делал, то результат был вот таким "5714.29%" вместо "57.14%". Где ошибка я так и не понял. Можете подсказать?

# %%
queries = [ 'смотреть сериалы онлайн', 'новости спорта', 'афиша кино', 'курс доллара', 'сериалы этим летом', 'курс по питону', 'сериалы про спорт']

item_all = len(queries)

item_3 = 0
item_2 = 0

for item in queries:
    if len(item.split(' ')) == 3:
        item_3 += 1
    if len(item.split(' ')) == 2:
        item_2 += 1

item_3_proc = item_3 / item_all * 100
item_2_proc = item_2 / item_all * 100        

print('Поисковых запросов, содержащих 2 слов(а): {:.2f}%'.format(item_2_proc))
print('Поисковых запросов, содержащих 3 слов(а): {:.2f}%'.format(item_3 / item_all * 100))
    
    #print(item, len(item), item.find('с'))

#if len(item) == 3:
 #   item_3 = item_3 + 1
  #  print(item_3)
#print('Поисковых запросов, содержащих 2 слов(а): {:.1%}'.format(имя переменной))
# Out:
# Поисковых запросов, содержащих 2 слов(а): 42.86%
# Поисковых запросов, содержащих 3 слов(а): 57.14%
